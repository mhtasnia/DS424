# %% [markdown]
# <a href="https://colab.research.google.com/github/mhtasnia/DS424/blob/main/DS424_lab_performance_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data(path="mnist.npz")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
from tensorflow.keras import layers

x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

inputs = keras.Input(shape=(28, 28), name='input_layer')
x = layers.Flatten()(inputs)
# Build model
x = layers.Dense(128) (x)
x = layers.BatchNormalization() (x)
x = layers.Activation('relu') (x)
x = layers.Dropout(0.3) (x)

x = layers.Dense(64) (x)
x = layers.BatchNormalization() (x)
x = layers.Activation('relu') (x)

outputs = layers.Dense(10, activation='softmax', name='output_layer_bn')(x)

model = keras.Model(inputs=inputs, outputs=outputs, name='mnist_bn_model2')

model.summary()
# Out:
# Model: "mnist_bn_model2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer_bn (Dense)         │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 110,154 (430.29 KB)
#  Trainable params: 109,770 (428.79 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
model.compile(optimizer='rmsprop',
loss='sparse_categorical_crossentropy',
metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=5, batch_size=64, validation_split=0.1)
# Out:
# Epoch 1/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8357 - loss: 0.5732 - val_accuracy: 0.9643 - val_loss: 0.1155
# Epoch 2/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9404 - loss: 0.1930 - val_accuracy: 0.9712 - val_loss: 0.0950
# Epoch 3/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9540 - loss: 0.1481 - val_accuracy: 0.9780 - val_loss: 0.0766
# Epoch 4/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9603 - loss: 0.1286 - val_accuracy: 0.9785 - val_loss: 0.0697
# Epoch 5/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9638 - loss: 0.1175 - val_accuracy: 0.9777 - val_loss: 0.0798

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test Accuracy: {test_acc}, Test Loss: {test_loss}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9692 - loss: 0.0999
# Test Accuracy: 0.9750000238418579, Test Loss: 0.08347508311271667

# %%
from sklearn.metrics import classification_report
import numpy as np

y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

report = classification_report(y_test, y_pred_classes)
print(report)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       980
#            1       0.98      0.99      0.99      1135
#            2       0.97      0.98      0.98      1032
#            3       0.98      0.97      0.97      1010
#            4       0.96      0.99      0.97       982
#            5       0.97      0.97      0.97       892
#            6       0.97      0.98      0.98       958
#            7       0.97      0.96      0.97      1028
#            8       0.98      0.96      0.97       974
#            9       0.98      0.95      0.97      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.98      0.97      0.97     10000

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np

# Binarize the output
n_classes = 10
y_test_binarized = label_binarize(y_test, classes=np.arange(n_classes))

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves
plt.figure(figsize=(10, 8))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve of class {i} (area = {roc_auc[i]:0.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Save the model to Google Drive
save_path = '/content/drive/MyDrive/performance_model.keras'
model.save(save_path)
print(f' Model saved successfully to {save_path}')
# Out:
#  Model saved successfully to /content/drive/MyDrive/performance_model.keras

# %%
load_path = '/content/drive/MyDrive/performance_model.keras'
restored_model = keras.models.load_model(load_path)
print(f'Model loaded successfully from {load_path}')
# Out:
# Model loaded successfully from /content/drive/MyDrive/performance_model.keras

# %%
(x2_train, y2_train), (x2_test, y2_test) = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 20s 0us/step

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 5, figsize=(10, 10))
axes = axes.flatten()
for i in range(5):
    img = x2_train[i]
    ax = axes[i]
    ax.imshow(img)
    ax.set_title(f"Label: {y2_train[i][0]}")
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras import layers

x2_train = x2_train.astype('float32') / 255.0
x2_test = x2_test.astype('float32') / 255.0

inputs = keras.Input(shape=(32, 32, 3), name='input_layer')

# %%
base_model = keras.applications.ResNet50(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(32, 32, 3),
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
    name="resnet50",
)

x = base_model.output

x = keras.layers.GlobalAveragePooling2D()(x)

x = keras.layers.Dropout(0.5)(x)

num_classes = 10
predictions = keras.layers.Dense(num_classes, activation="softmax")(x)


model2 = keras.Model(inputs=base_model.input, outputs=predictions)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
model2.compile(optimizer='rmsprop',
loss='sparse_categorical_crossentropy',
metrics=['accuracy'])
history_2 = model2.fit(x2_train, y2_train, epochs=100, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 44ms/step - accuracy: 0.8431 - loss: 0.6877 - val_accuracy: 0.6150 - val_loss: 26.6656
# Epoch 2/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.8267 - loss: 0.7522 - val_accuracy: 0.7098 - val_loss: 3.7740
# Epoch 3/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 36s 26ms/step - accuracy: 0.8338 - loss: 0.6670 - val_accuracy: 0.6492 - val_loss: 10.1396
# Epoch 4/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.8294 - loss: 0.6805 - val_accuracy: 0.6828 - val_loss: 8.1268
# Epoch 5/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.8447 - loss: 0.6359 - val_accuracy: 0.3992 - val_loss: 8.3553
# Epoch 6/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.8329 - loss: 0.6912 - val_accuracy: 0.5510 - val_loss: 2.7408
# Epoch 7/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.8512 - loss: 0.6156 - val_accuracy: 0.4900 - val_loss: 31.8518
# Epoch 8/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 38s 27ms/step - accuracy: 0.8549 - loss: 0.5560 - val_accuracy: 0.4340 - val_loss: 14.5350
# Epoch 9/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 36s 26ms/step - accuracy: 0.8601 - loss: 0.6037 - val_accuracy: 0.4212 - val_loss: 74.9895
# Epoch 10/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 36s 26ms/step - accuracy: 0.8643 - loss: 0.5788 - val_accuracy: 0.6080 - val_loss: 10.4099
# Epoch 11/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.8772 - loss: 0.5082 - val_accuracy: 0.6670 - val_loss: 3.7150
# Epoch 12/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 36s 26ms/step - accuracy: 0.8846 - loss: 0.4589 - val_accuracy: 0.5354 - val_loss: 24.0424
# Epoch 13/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.8865 - loss: 0.4664 - val_accuracy: 0.4528 - val_loss: 4.6154
# Epoch 14/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.8908 - loss: 0.4835 - val_accuracy: 0.3804 - val_loss: 7.4538
# Epoch 15/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 38s 27ms/step - accuracy: 0.8965 - loss: 0.4788 - val_accuracy: 0.5148 - val_loss: 14.3069
# Epoch 16/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 36s 26ms/step - accuracy: 0.9009 - loss: 0.4537 - val_accuracy: 0.2570 - val_loss: 127.9870
# Epoch 17/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9027 - loss: 0.4457 - val_accuracy: 0.5504 - val_loss: 24.5534
# Epoch 18/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9095 - loss: 0.4755 - val_accuracy: 0.5468 - val_loss: 3763.3225
# Epoch 19/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9069 - loss: 0.4638 - val_accuracy: 0.3768 - val_loss: 227.4382
# Epoch 20/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9153 - loss: 0.3802 - val_accuracy: 0.5586 - val_loss: 29.9676
# Epoch 21/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 36s 26ms/step - accuracy: 0.9144 - loss: 0.4326 - val_accuracy: 0.5946 - val_loss: 62.8992
# Epoch 22/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9216 - loss: 0.3700 - val_accuracy: 0.5186 - val_loss: 16.2920
# Epoch 23/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9205 - loss: 0.3827 - val_accuracy: 0.5372 - val_loss: 3.6743
# Epoch 24/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9183 - loss: 0.4246 - val_accuracy: 0.5756 - val_loss: 15.9349
# Epoch 25/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.9175 - loss: 0.4820 - val_accuracy: 0.4594 - val_loss: 34.1486
# Epoch 26/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9200 - loss: 0.4765 - val_accuracy: 0.4728 - val_loss: 19.3216
# Epoch 27/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 36s 26ms/step - accuracy: 0.9218 - loss: 0.4277 - val_accuracy: 0.6932 - val_loss: 7.0875
# Epoch 28/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 36s 26ms/step - accuracy: 0.
100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9810 - loss: 0.1270 - val_accuracy: 0.7692 - val_loss: 2.0187
# Epoch 88/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9814 - loss: 0.1429 - val_accuracy: 0.7832 - val_loss: 2.5848
# Epoch 89/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9810 - loss: 0.1469 - val_accuracy: 0.7800 - val_loss: 2.7219
# Epoch 90/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 38s 27ms/step - accuracy: 0.9804 - loss: 0.1477 - val_accuracy: 0.7646 - val_loss: 10.9236
# Epoch 91/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9803 - loss: 0.1124 - val_accuracy: 0.7596 - val_loss: 80.9064
# Epoch 92/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9842 - loss: 0.1149 - val_accuracy: 0.7824 - val_loss: 5.3907
# Epoch 93/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9831 - loss: 0.1231 - val_accuracy: 0.7254 - val_loss: 23.9236
# Epoch 94/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9803 - loss: 0.1212 - val_accuracy: 0.7898 - val_loss: 9.9543
# Epoch 95/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9842 - loss: 0.1004 - val_accuracy: 0.7898 - val_loss: 8.2649
# Epoch 96/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9837 - loss: 0.0898 - val_accuracy: 0.7948 - val_loss: 2.5821
# Epoch 97/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9847 - loss: 0.1076 - val_accuracy: 0.7652 - val_loss: 2.6374
# Epoch 98/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 26ms/step - accuracy: 0.9835 - loss: 0.0932 - val_accuracy: 0.7882 - val_loss: 2.3265
# Epoch 99/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 27ms/step - accuracy: 0.9833 - loss: 0.1093 - val_accuracy: 0.7780 - val_loss: 2.3597
# Epoch 100/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 37s 27ms/step - accuracy: 0.9848 - loss: 0.0787 - val_accuracy: 0.7764 - val_loss: 2.8790

# %%
save_path_model2 = '/content/drive/MyDrive/cifar10_resnet50_model_final.keras'
model2.save(save_path_model2)
print(f'Model2 saved successfully to {save_path_model2}')
# Out:
# Model2 saved successfully to /content/drive/MyDrive/cifar10_resnet50_model_final.keras

# %%
test_loss_2, test_acc_2 = model2.evaluate(x2_test, y2_test)
print(f'Test Accuracy: {test_acc_2}, Test Loss: {test_loss_2}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.7507 - loss: 2.9773
# Test Accuracy: 0.7534999847412109, Test Loss: 3.1753268241882324

# %%
from sklearn.metrics import classification_report
import numpy as np

y2_pred = model2.predict(x2_test)
y2_pred_classes = np.argmax(y2_pred, axis=1)

report2 = classification_report(y2_test, y2_pred_classes)
print(report2)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step
#               precision    recall  f1-score   support
#
#            0       0.71      0.84      0.77      1000
#            1       0.87      0.86      0.86      1000
#            2       0.67      0.73      0.70      1000
#            3       0.62      0.54      0.58      1000
#            4       0.80      0.70      0.75      1000
#            5       0.81      0.51      0.62      1000
#            6       0.87      0.75      0.81      1000
#            7       0.77      0.84      0.80      1000
#            8       0.67      0.94      0.78      1000
#            9       0.82      0.82      0.82      1000
#
#     accuracy                           0.75     10000
#    macro avg       0.76      0.75      0.75     10000
# weighted avg       0.76      0.75      0.75     10000

# %%
import matplotlib.pyplot as plt

plt.plot(history_2.history['accuracy'], label='Train Accuracy')
plt.plot(history_2.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy for Model 2 (CIFAR-10)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history_2.history['loss'], label='Train Loss')
plt.plot(history_2.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss for Model 2 (CIFAR-10)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np

# Binarize the output
n_classes = 10
y_test_binarized = label_binarize(y2_test, classes=np.arange(n_classes))

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], y2_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves
plt.figure(figsize=(10, 8))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve of class {i} (area = {roc_auc[i]:0.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Model 2 (CIFAR-10)')
plt.legend()
plt.show()
